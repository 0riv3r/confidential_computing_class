# %% [markdown]
# You are a Python and Cryptography expert AI bot who helps developers write correct and secure code.
#
# Write a Python code using the PySyft package that gets an array of integers and returns the sum of all the integers without knowing or revealing any of the input real values.  Only use the PySyft package version syft 0.9.5.

# %%
# !pip install syft==0.9.5

# %%
# !python -c "import syft; print(syft.__version__)"
# Out:
# /home/orivlinux/miniforge3/envs/ccc/lib/python3.11/site-packages/paramiko/pkey.py:100: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /home/orivlinux/miniforge3/envs/ccc/lib/python3.11/site-packages/paramiko/transport.py:259: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# 0.9.5
